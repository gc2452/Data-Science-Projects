# %% [markdown]
# # Economic Impact of Advancing Women’s Education, Employment & Leadership

# %%
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
import seaborn as sb
sb.set_style("darkgrid")
# %matplotlib inline

# %%
# %pwd
# Out:
# u'/Users/Geraldine/Documents/Data Science Projects/Economics of Gender'

# %%
df = pd.read_csv('Popular Indicators (1)/531298ca-64b7-484d-b11e-3e500919935b_Data.csv')

# %% [markdown]
# ## RAW DATA FORMAT

# %%
df.head()
# Out:
#          Series Name     Series Code Country Name Country Code 2014 [YR2014]
# 0  GDP (current US$)  NY.GDP.MKTP.CD  Afghanistan          AFG   20050189882
# 1  GDP (current US$)  NY.GDP.MKTP.CD    Australia          AUS   1.45468E+12
# 2  GDP (current US$)  NY.GDP.MKTP.CD   Bangladesh          BGD   1.72885E+11
# 3  GDP (current US$)  NY.GDP.MKTP.CD     Barbados          BRB    4352734313
# 4  GDP (current US$)  NY.GDP.MKTP.CD       Belize          BLZ    1717861730

# %% [markdown]
# ## PIVOT TABLE THAT ORGANIZES DIFF SERIES BY COUNTRY

# %%
table = pd.pivot_table(df, values='2014 [YR2014]', index=['Country Name'], columns=['Series Name'], aggfunc=np.sum)

# %%
table
# Out:
# Series Name            Children in employment, study and work, female (% of female children in employment, ages 7-14)  \
# Country Name
# Afghanistan                                                            ..
# Albania                                                                ..
# Argentina                                                              ..
# Armenia                                                                ..
# Australia                                                              ..
# Austria                                                                ..
# Bangladesh                                                             ..
# Barbados                                                               ..
# Belize                                                                 ..
# Bolivia                                                                ..
# Bosnia and Herzegovina                                                 ..
# ...

# %% [markdown]
# ## RESET THE INDEX

# %%
tablereset = table.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='')

# %%
tablereset['GDP (current US$)'] = tablereset['GDP (current US$)'].apply(pd.to_numeric,errors='coerce')

# %%
tablereset2 = tablereset['GDP (current US$)'].dropna()

# %% [markdown]
# ## CONVERT TYPE OBJECT TO NUMERIC

# %%
tablereset2['GDP (current US$)'] = tablereset2['GDP (current US$)'].apply(pd.to_numeric,errors='coerce') #uses pandas

# %%
tablereset2['GDP (current US$)'] = tablereset2['GDP (current US$)'].convert_objects(convert_numeric=True) #uses python

# %% [markdown]
# ## CHECK THAT THE TYPE IS FLOAT & SAVE AS CSV FOR ANALYSIS

# %%
tablereset2['GDP (current US$)']

# %%
tablereset.to_csv('tablereset.csv')
